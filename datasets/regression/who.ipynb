# %%
import numpy as np
import matplotlib.pyplot as plt

data = [
    {'average': np.array([[13958.4483283 , 13696.97151006, 13265.0071498 , 13077.20189804]]),
     'values': [np.array(['northeast', 'northwest', 'southeast', 'southwest'], dtype=object)]},
    
    {'average': np.array([[13208.3935364 , 13516.64659173]]),
     'values': [np.array([0, 1], dtype=int)]},
    
    {'average': np.array([[8461.23079548, 32319.11367906]]),
     'values': [np.array([0, 1], dtype=int)]}
]

# Extracting data
labels = data[0]['values'][0]
x = np.arange(len(labels))
width = 0.2  # Width of the bars

# Create subplots
fig, ax = plt.subplots()

# Plotting the bars
for i, dataset in enumerate(data):
    average_values = dataset['average'][0]
    ax.bar(x + i * width, average_values, width, label=f'Dataset {i+1}')

# Adding labels and title
ax.set_xlabel('Regions' if len(labels) > 2 else 'Values')
ax.set_ylabel('Average Values')
ax.set_title('Grouped Bar Plot')
ax.set_xticks(x + (len(data) - 1) * width / 2)
ax.set_xticklabels(labels)

# Adding legend
ax.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 26
#      24 for i, dataset in enumerate(data):
#      25     average_values = dataset['average'][0]
# ---> 26     ax.bar(x + i * width, average_values, width, label=f'Dataset {i+1}')
#      28 # Adding labels and title
#      29 ax.set_xlabel('Regions' if len(labels) > 2 else 'Values')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
# ...
