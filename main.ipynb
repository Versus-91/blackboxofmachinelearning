# %%
import sklearn
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
print(sklearn.__version__)
from interpret import show
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
import numpy as np
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from sklearn.linear_model import LogisticRegression
from interpret.glassbox import LogisticRegression as LR
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
# Out:
# 1.4.dev0

# %% [markdown]
# glass box models like decission trees, linear regression, and logistic regression are easy to understand by design.
# but they have problem with understanding non linear relations and feature interaction.

# %%
data = load_breast_cancer()
X, y = load_breast_cancer(return_X_y=True, as_frame=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
model = LogisticRegression(max_iter=3000, random_state=42)
model.fit(X_train, y_train)
# Retrieve the feature names and coefficients
feature_names = data.feature_names
coefficients = model.coef_[0]

feature_names = data.feature_names
coefficients = model.coef_[0]

# Calculate the exponentiated coefficients
exp_coefficients = np.exp(coefficients)
threshold = 0.2
# Create a DataFrame to display the coefficients and their exponentiated values
coef_table = pd.DataFrame(
    {'Feature': feature_names, 'Coefficient': coefficients, 'Exp(Coefficient)': exp_coefficients})
important_features = coef_table[abs(coef_table['Coefficient']) > threshold]

# Display the table
display(important_features)
# Out:
#                  Feature  Coefficient  Exp(Coefficient)
# 0            mean radius     0.973149          2.646265
# 1           mean texture     0.225288          1.252683
# 2         mean perimeter    -0.363911          0.694953
# 5       mean compactness    -0.228639          0.795615
# 6         mean concavity    -0.522683          0.592928
# 7    mean concave points    -0.276596          0.758361
# 8          mean symmetry    -0.222316          0.800662
# 11         texture error     1.384524          3.992925
# 21         worst texture    -0.513572          0.598355
# 24      worst smoothness    -0.306190          0.736247
# 25     worst compactness    -0.760756          0.467313
# 26       worst concavity    -1.423762          0.240806
# 27  worst concave points    -0.500510          0.606222
# 28        worst symmetry    -0.728828          0.482474

# %% [markdown]
# table explaination : an increase in the mean radius of tumor changes the odds of maliignt tumor by a factor of 2.68

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
# Load the Titanic dataset (you can download it from various sources or use libraries to fetch it)
# Here, we assume you have the dataset in a CSV file named "titanic.csv"
titanic_data = pd.read_csv("datasets/your_dataset.csv")

# Define the features (including both numerical and categorical)
# For example, let's consider 'Age' (numerical) and 'Sex' and 'Pclass' (categorical)
features = ['Age', 'Sex', 'Pclass']

# Select the target variable ('Survived' in this case)
target = 'Survived'

# Split the data into training and testing sets
X = titanic_data[features]
y = titanic_data[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Preprocessing for the categorical features (e.g., one-hot encoding)
categorical_features = ['Sex', 'Pclass']
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', ['Age']),
        ('cat', categorical_transformer, categorical_features)
    ])

# Create and train a logistic regression model
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('classifier', LogisticRegression(max_iter=1000))])

model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\versu\Desktop\research\eai\main.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/versu/Desktop/research/eai/main.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> from sklearn.pipeline import Pipeline
#       <a href='vscode-notebook-cell:/c%3A/Users/versu/Desktop/research/eai/main.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> # Load the Titanic dataset (you can download it from various sources or use libraries to fetch it)
#       <a href='vscode-notebook-cell:/c%3A/Users/versu/Desktop/research/eai/main.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> # Here, we assume you have the dataset in a CSV file named "titanic.csv"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/versu/Desktop/research/eai/main.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> titanic_data = pd.read_csv("datasets/your_dataset.csv")
# ...

# %% [markdown]
# to do check categorical feature and multimonal logistic regresion
